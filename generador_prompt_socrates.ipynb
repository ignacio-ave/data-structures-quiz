# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import bool
#
# ModuleNotFoundError: No module named 'bool'

# %%
estructuras_de_datos = pd.DataFrame({
    'Estructura de datos': ['Arreglo', 'Lista enlazada', 'Lista enlazada simple', 'Lista enlazada doble', 
                           'Lista enlazada circular', 'Pila', 'Cola', 'Cola simple', 'Cola doble', 
                           'Cola de prioridad', 'Arreglo asociativo', 'Tabla Hash', 'Árbol', 
                           'Árbol binario de búsqueda', 'Árbol AVL', 'Árbol Rojo-Negro', 'Árbol B', 
                           'Árbol B+', 'Árbol de segmentos', 'Árbol de sufijos', 'Grafo', 'Grafo dirigido', 
                           'Grafo no dirigido', 'Grafo ponderado', 'Montículo', 'Montículo binario', 
                           'Montículo binomial', 'Montículo de Fibonacci'],
    'TDAs asociados': ['Arreglo', 'Lista enlazada', 'Lista enlazada', 'Lista enlazada', 'Lista enlazada', 
                       'Pila', 'Cola', 'Cola', 'Cola', 'Cola', 'Arreglo asociativo', 'Arreglo asociativo', 
                       'Árbol', 'Árbol', 'Árbol', 'Árbol', 'Árbol', 'Árbol', 'Árbol', 'Árbol', 'Grafo', 
                       'Grafo', 'Grafo', 'Grafo', 'Montículo', 'Montículo', 'Montículo', 'Montículo']
})

estructuras_de_datos
# Out:
#           Estructura de datos      TDAs asociados
# 0                     Arreglo             Arreglo
# 1              Lista enlazada      Lista enlazada
# 2       Lista enlazada simple      Lista enlazada
# 3        Lista enlazada doble      Lista enlazada
# 4     Lista enlazada circular      Lista enlazada
# 5                        Pila                Pila
# 6                        Cola                Cola
# 7                 Cola simple                Cola
# 8                  Cola doble                Cola
# 9           Cola de prioridad                Cola
# 10         Arreglo asociativo  Arreglo asociativo
# 11                 Tabla Hash  Arreglo asociativo
# 12                      Árbol               Árbol
# 13  Árbol binario de búsqueda               Árbol
# 14                  Árbol AVL               Árbol
# 15           Árbol Rojo-Negro               Árbol
# 16                    Árbol B               Árbol
# 17                   Árbol B+               Árbol
# ...

# %%
estructuras_datos_operaciones = {
    'Arreglo': ['Acceder a un elemento por índice', 'Modificar un elemento por índice', 'Buscar un elemento'],
    'Lista enlazada simple': ['Acceder a un elemento por índice', 'Insertar un elemento al inicio', 'Insertar un elemento al final', 'Eliminar un elemento'],
    'Lista enlazada doble': ['Acceder a un elemento por índice', 'Insertar un elemento al inicio', 'Insertar un elemento al final', 'Eliminar un elemento'],
    'Lista enlazada circular': ['Acceder a un elemento por índice', 'Insertar un elemento al inicio', 'Insertar un elemento al final', 'Eliminar un elemento'],
    'Pila': ['Apilar un elemento', 'Desapilar un elemento'],
    'Cola simple': ['Encolar un elemento', 'Desencolar un elemento'],
    'Cola doble': ['Encolar un elemento al inicio', 'Encolar un elemento al final', 'Desencolar un elemento del inicio', 'Desencolar un elemento del final'],
    'Cola de prioridad': ['Encolar un elemento con prioridad', 'Desencolar un elemento con mayor prioridad'],
    'Tabla Hash': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol binario de búsqueda': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol AVL': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol Rojo-Negro': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol B': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol B+': ['Insertar un elemento', 'Eliminar un elemento', 'Buscar un elemento'],
    'Árbol de segmentos': ['Consultar el valor de un rango', 'Modificar el valor de un elemento', 'Consultar el valor de un elemento'],
    'Árbol de sufijos': ['Buscar un patrón en una cadena'],
    'Grafo dirigido': ['Agregar un vértice', 'Eliminar un vértice', 'Agregar una arista', 'Eliminar una arista'],
    'Grafo no dirigido': ['Agregar un vértice', 'Eliminar un vértice', 'Agregar una arista', 'Eliminar una arista'],
    'Grafo ponderado': ['Agregar un vértice', 'Eliminar un vértice', 'Agregar una arista con peso', 'Eliminar una arista con peso'],
    'Montículo binario': ['Insertar un elemento', 'Eliminar el elemento con mayor prioridad'],
    'Montículo binomial': ['Insertar un elemento', 'Eliminar el elemento con mayor prioridad'],
    'Montículo de Fibonacci': ['Insertar un elemento', 'Eliminar el elemento con mayor prioridad']
}
(estructuras_datos_operaciones)
# Out:
# {'Arreglo': ['Acceder a un elemento por índice',
#   'Modificar un elemento por índice',
#   'Buscar un elemento'],
#  'Lista enlazada simple': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Lista enlazada doble': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Lista enlazada circular': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Pila': ['Apilar un elemento', 'Desapilar un elemento'],
#  'Cola simple': ['Encolar un elemento', 'Desencolar un elemento'],
#  'Cola doble': ['Encolar un elemento al inicio',
#   'Encolar un elemento al final',
#   'Desencolar un elemento del inicio',
#   'Desencolar un elemento del final'],
#  'Cola de prioridad': ['Encolar un elemento con prioridad',
# ...

# %%
# agregar
df = pd.DataFrame(estructuras_datos_operaciones.items(), columns=['Estructura de Datos', 'Operaciones'])
df.set_index('Estructura de Datos', inplace=True)
df = df.explode('Operaciones')
df.reset_index(inplace=True)
print(df)
# Out:
#        Estructura de Datos                               Operaciones
# 0                  Arreglo          Acceder a un elemento por índice
# 1                  Arreglo          Modificar un elemento por índice
# 2                  Arreglo                        Buscar un elemento
# 3    Lista enlazada simple          Acceder a un elemento por índice
# 4    Lista enlazada simple            Insertar un elemento al inicio
# ..                     ...                                       ...
# 60       Montículo binario  Eliminar el elemento con mayor prioridad
# 61      Montículo binomial                      Insertar un elemento
# 62      Montículo binomial  Eliminar el elemento con mayor prioridad
# 63  Montículo de Fibonacci                      Insertar un elemento
# 64  Montículo de Fibonacci  Eliminar el elemento con mayor prioridad
#
# [65 rows x 2 columns]

# %%
def imprimir_socrates_gpt(tema, objetivo):
    print(f"Nombre: Socrates-gpt")
    print(f"Funcion: Generar preguntas socraticas consecutivas una por una para ir midiendo y ayudando a entender en mayor profundidad los temas tratados.")
    print(f"Objetivos: {objetivo}")
    print(f"Instrucciones adicionales: ['debes llevar el conteo de las respuestas correctas consecutivas', 'si la respuesta es erronea, argumenta el porque de una manera que facilite la comprecion de los conceptos erroneos','debes llevar el conteo de las respuestas erroneas consecutivas', 'si el usuario lleva mas de tres respuestas consecutivas erroneas se debe mostrar una cheatsheet del tema y la materia tratada y bajar el nivel de dificultad de las preguntas drasticamente']")
    print(f"El tema tratado en las preguntas es: {tema}")
    print(f"Las preguntas deben estar pensadas para realizar este objetivo: {objetivo}")
    print(f"Intrucciones adicionales : ['debes llevar el conteo de las respuestas correctas consecutivas', 'si la respuesta es erronea, argumenta el porque de una manera que facilite la comprecion de los conceptos erroneos','debes llevar el conteo de las respuestas erroneas consecutivas', 'si el usuario lleva mas de tres respuestas consecutivas erroneas se debe mostrar una cheatsheet del tema y la materia tratada y bajar el nivel de dificultad de las preguntas drasticamente' ]")
    
    print(f"Debes presentarte como socrates-gpt y personificar a socrates.")
    
def elegir_tema():

def get_temas():
    
    while(True):
        elegir_tema()
        
return list(df['Estructura de Datos'].unique())

# %%
# main  
def main():
    temas = get_temas()

# %% [markdown]
# Nombre: Socrates-gpt
# Funcion: Generar preguntas socraticas consecutivas una por una para ir midiendo y ayudando a entender en mayor profundidad los temas tratados.
# Objetivos: ['Generar una pregunta que mida el conocimiento y a la vez ayude a entender los contenidos', 'La primera pregunta es standard y conceptual', 'Ajustar la dificultad de las preguntas socraticas segun los niveles de conocimiento demostrados del encuestado','Si hay menos de seis respuestas correctas consecutivas solo se debe realizar una pregunta socratica','Si hay mas de seis respuestas correctas concecutivas, el formato de las preguntas se debe cambiar, el nuevo formato consta de dos preguntas al mismo tiempo, una socratica, y otra se relaciona a la primera pregunta pero trata de la aplicacion,complejidad temporal,etc','el tema tratado en las preguntas es: {tema}' ,'Las preguntas deben estar pensadas para realizar este objetivo: {objetivo}' ,  ]
# Intrucciones adicionales : ['debes llevar el conteo de las respuestas correctas consecutivas', 'si la respuesta es erronea, argumenta el porque de una manera que facilite la comprecion de los conceptos erroneos','debes llevar el conteo de las respuestas erroneas consecutivas', 'si el usuario lleva mas de tres respuestas consecutivas erroneas se debe mostrar una cheatsheet del tema y la materia tratada y bajar el nivel de dificultad de las preguntas drasticamente' ]
#
# Debes presentarte como socrates-gpt y personificar a socrates.
#
# Informacion acerca de {tema} :  {operaciones} {complejidad temporal}
#
# Informacion acerca de {tda} : {operaciones}
#
#
#
# ---
# {'Arreglo': ['Acceder a un elemento por índice',
#   'Modificar un elemento por índice',
#   'Buscar un elemento'],
#  'Lista enlazada simple': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Lista enlazada doble': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Lista enlazada circular': ['Acceder a un elemento por índice',
#   'Insertar un elemento al inicio',
#   'Insertar un elemento al final',
#   'Eliminar un elemento'],
#  'Pila': ['Apilar un elemento', 'Desapilar un elemento'],
#  'Cola simple': ['Encolar un elemento', 'Desencolar un elemento'],
#  'Cola doble': ['Encolar un elemento al inicio',
#   'Encolar un elemento al final',
#   'Desencolar un elemento del inicio',
#   'Desencolar un elemento del final'],
#  'Cola de prioridad': ['Encolar un elemento con prioridad',
#   'Desencolar un elemento con mayor prioridad'],
#  'Tabla Hash': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol binario de búsqueda': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol AVL': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol Rojo-Negro': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol B': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol B+': ['Insertar un elemento',
#   'Eliminar un elemento',
#   'Buscar un elemento'],
#  'Árbol de segmentos': ['Consultar el valor de un rango',
#   'Modificar el valor de un elemento',
#   'Consultar el valor de un elemento'],
#  'Árbol de sufijos': ['Buscar un patrón en una cadena'],
#  'Grafo dirigido': ['Agregar un vértice',
#   'Eliminar un vértice',
#   'Agregar una arista',
#   'Eliminar una arista'],
#  'Grafo no dirigido': ['Agregar un vértice',
#   'Eliminar un vértice',
#   'Agregar una arista',
#   'Eliminar una arista'],
#  'Grafo ponderado': ['Agregar un vértice',
#   'Eliminar un vértice',
#   'Agregar una arista con peso',
#   'Eliminar una arista con peso'],
#  'Montículo binario': ['Insertar un elemento',
#   'Eliminar el elemento con mayor prioridad'],
#  'Montículo binomial': ['Insertar un elemento',
#   'Eliminar el elemento con mayor prioridad'],
#  'Montículo de Fibonacci': ['Insertar un elemento',
#   'Eliminar el elemento con mayor prioridad']}
#
#   ---
#   	Estructura de datos	TDAs asociados
# 0	Arreglo	Arreglo
# 1	Lista enlazada	Lista enlazada
# 2	Lista enlazada simple	Lista enlazada
# 3	Lista enlazada doble	Lista enlazada
# 4	Lista enlazada circular	Lista enlazada
# 5	Pila	Pila
# 6	Cola	Cola
# 7	Cola simple	Cola
# 8	Cola doble	Cola
# 9	Cola de prioridad	Cola
# 10	Arreglo asociativo	Arreglo asociativo
# 11	Tabla Hash	Arreglo asociativo
# 12	Árbol	Árbol
# 13	Árbol binario de búsqueda	Árbol
# 14	Árbol AVL	Árbol
# 15	Árbol Rojo-Negro	Árbol
# 16	Árbol B	Árbol
# 17	Árbol B+	Árbol
# 18	Árbol de segmentos	Árbol
# 19	Árbol de sufijos	Árbol
# 20	Grafo	Grafo
# 21	Grafo dirigido	Grafo
# 22	Grafo no dirigido	Grafo
# 23	Grafo ponderado	Grafo
# 24	Montículo	Montículo
# 25	Montículo binario	Montículo
# 26	Montículo binomial	Montículo
# 27	Montículo de Fibonacci	Montículo

# %% [markdown]
# Necesito que generes preguntas socraticas consecutivas una por una para ir midiendo y ayudando a enteder en mayor profunidad los temas tratados.
# Debes presentar una pregunta y luego yo te dare la respuesta a esta. si la respuesta es errada, debes hacerme una pregunta que evidencie eso. pero si mi respuesta es acertada debes ir profundizando en el tema de manera sutil y consecutiva hasta que exista un error o hasta que se consigan 8 preguntas consecutivas acertadas.
#
# si se llegan hasta las 8 preguntas consecutivas acertadas debes mostrar un mensaje felicitando al alumno y dando a entender que conoce la materia muy bien.
#
# necesito que lleves el conteo de las preguntas concecutivas respondidas correctamente
#
#
# en este caso el tema a tratar sera :
#
# y el objetivo de las preguntas es :
