# %% [markdown]
# ### Actividades clase

# %% [markdown]
# quiero que generes un codigo en python para una jupyter notebook, necesito que generes un dataframe o una serie con todas las estructura de datos y otro con los tdas, y luego quiero que generes funciones a las cuales se les paso una string con informacion adicional, y el nombre de una estructura de datos o un tda (tambien puede ser mas de uno), necesito que cada funcion tenga generalice un tipo de actividad :
#
#     Implementación básica: Implementar cada estructura de datos desde cero, incluyendo sus operaciones básicas (inserción, eliminación, búsqueda, etc.).
#
#     Operaciones avanzadas: Implementar operaciones adicionales específicas para cada estructura de datos, como equilibrado de árboles, hash functions personalizadas, etc.
#
#     Análisis de rendimiento: Realizar análisis de tiempo y espacio de las operaciones en cada estructura de datos, y comparar sus resultados.
#
#     Casos de uso: Identificar y desarrollar ejemplos prácticos donde cada estructura de datos sea la opción más adecuada, explicando por qué.
#
#     Adaptación: Modificar cada estructura de datos para adaptarla a casos específicos, como arreglos con elementos de diferentes tipos, listas enlazadas doblemente enlazadas, etc.
#
#     Fusión e interacción: Combinar dos o más estructuras de datos para resolver un problema particular, como utilizar un árbol B+ para indexar un arreglo ordenado.
#
#     Visualización: Crear representaciones gráficas de cada estructura de datos, para facilitar su comprensión y análisis.
#
#     Persistencia: Implementar métodos de almacenamiento y recuperación de cada estructura de datos en archivos o bases de datos.
#
#     Pruebas unitarias: Diseñar e implementar pruebas unitarias para verificar la correcta funcionalidad de cada estructura de datos y sus operaciones.
#
#     Optimización: Estudiar e implementar técnicas de optimización para cada estructura de datos, como compresión de datos, uso eficiente de la memoria caché, etc.
#
#     Estudio comparativo: Realizar un estudio comparativo de las diferentes estructuras de datos, analizando sus ventajas y desventajas en función de factores como tiempo de ejecución, uso de memoria, complejidad de implementación, etc.
#
#
#
# ---
# Estructuras de datos:
#
#         Arreglo (Array)
#     Lista enlazada (Linked List)
#         Lista enlazada simple (Singly Linked List)
#         Lista enlazada doble (Doubly Linked List)
#         Lista enlazada circular (Circular Linked List)
#     Pila (Stack)
#     Cola (Queue)
#         Cola simple (Simple Queue)
#         Cola doble (Double-ended Queue, Deque)
#         Cola de prioridad (Priority Queue)
#     Arreglo asociativo (Associative Array)
#         Tabla Hash (Hash Table)
#     Árbol (Tree)
#         Árbol binario de búsqueda (Binary Search Tree, BST)
#         Árbol AVL
#         Árbol Rojo-Negro (Red-Black Tree)
#         Árbol B
#         Árbol B+
#         Árbol de segmentos (Segment Tree)
#         Árbol de sufijos (Suffix Tree)
#     Grafo (Graph)
#         Grafo dirigido (Directed Graph)
#         Grafo no dirigido (Undirected Graph)
#         Grafo ponderado (Weighted Graph)
#     Montículo (Heap)
#         Montículo binario (Binary Heap)
#         Montículo binomial (Binomial Heap)
#         Montículo de Fibonacci (Fibonacci Heap)
#
# Tipos de Datos Abstractos (TDAs):
#
#     Conjunto (Set)
#     Mapa (Map)
#     Lista (List)
#     Pila (Stack)
#     Cola (Queue)
#     Grafo (Graph)
#     Árbol (Tree)
#     Diccionario (Dictionary)
#     Multiconjunto (Multiset)
#     Tupla (Tuple)

# %%
import pandas as pd

# %%
estructuras_datos = [
    'Arreglo (Array)',
    'Lista enlazada (Linked List)',
    'Pila (Stack)',
    'Cola (Queue)',
    'Arreglo asociativo (Associative Array)',
    'Árbol (Tree)',
    'Grafo (Graph)',
    'Montículo (Heap)',
]

tdas = [
    'Conjunto (Set)',
    'Mapa (Map)',
    'Lista (List)',
    'Pila (Stack)',
    'Cola (Queue)',
    'Grafo (Graph)',
    'Árbol (Tree)',
    'Diccionario (Dictionary)',
    'Multiconjunto (Multiset)',
    'Tupla (Tuple)',
]

estructuras_datos_series = pd.Series(estructuras_datos, name="Estructuras de Datos")
tdas_series = pd.Series(tdas, name="TDAs")

# %%
estructuras_definiciones = [
    '''
    typedef struct {
        int* data;
        int size;
    } Array;
    ''',
    '''
    typedef struct Node {
        int data;
        struct Node* next;
    } LinkedList;
    ''',
    '''
    typedef struct {
        int* data;
        int top;
        int capacity;
    } Stack;
    ''',
    '''
    typedef struct {
        int* data;
        int front;
        int rear;
        int capacity;
    } Queue;
    ''',
    '''
    typedef struct KeyValue {
        int key;
        int value;
        struct KeyValue* next;
    } AssociativeArray;
    ''',
    '''
    typedef struct TreeNode {
        int data;
        struct TreeNode* left;
        struct TreeNode* right;
    } Tree;
    ''',
    '''
    typedef struct {
        int vertices;
        LinkedList* adjacencyList;
    } Graph;
    ''',
    '''
    typedef struct {
        int* priorities;
        int size;
        int capacity;
    } Heap;
    '''
]



operaciones = [
    ["Acceso", "búsqueda", "inserción", "eliminación"],
    ["Inserción", "eliminación", "búsqueda"],
    ["Push", "pop", "peek", "is_empty"],
    ["Enqueue", "dequeue", "peek", "is_empty"],
    ["Insertar", "eliminar", "buscar"],
    ["Inserción", "eliminación", "búsqueda", "recorrido"],
    ["Agregar vértice", "agregar arista", "eliminar vértice", "eliminar arista", "búsqueda"],
    ["Insertar", "eliminar", "buscar_min", "buscar_max", "incrementar_prioridad", "decrementar_prioridad"],
]





data_dict = {'Estructura de datos': estructuras_datos, 'Definición': estructuras_definiciones}

data_struct = pd.DataFrame(data_dict)


data_dict = {'Estructura de datos': estructuras_datos, 'Operaciones': operaciones}

operaciones_df = pd.DataFrame(data_dict)

# %% [markdown]
# Considere la siguiente estructura para el Montículo:
# typedef struct{
#   int* priorities; //arreglo de prioridades
#   int size; //cantidad de datos en el Heap
#   int capac; //tamaño actual del arreglo de prioridades
# }Heap; //Monticulo
#
#
# Ejemplo
#
# 1. Escriba una función para insertar un nuevo elemento al montículo.

# %%
def implementacion_basica(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    
    print(f"Considere la siguiente estructura para la generacion de la actividad {estructuras}: ")
    print(f"")
    print(f"")
    
    # Aquí va la implementación básica de las estructuras seleccionadas

# %%
def implementacion_basica(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    
    print(f"Considere la siguiente estructura para el {estructuras}: ")
    print(f"")
    print(f"")
    
    # Aquí va la implementación básica de las estructuras seleccionadas

def operaciones_avanzadas(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí van las operaciones avanzadas para las estructuras seleccionadas

def analisis_rendimiento(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va el análisis de rendimiento de las estructuras seleccionadas

def casos_uso(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí van los casos de uso de las estructuras seleccionadas

def adaptacion(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va la adaptación de las estructuras seleccionadas

def fusion_interaccion(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va la fusión e interacción de las estructuras seleccionadas

def visualizacion(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va la visualización de las estructuras seleccionadas

def persistencia(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va la persistencia de las estructuras seleccionadas

def pruebas_unitarias(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí van las pruebas unitarias de las estructuras seleccionadas

def optimizacion(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va la optimización de las estructuras seleccionadas

def estudio_comparativo(informacion, estructuras):
    print(f"Información adicional: {informacion}")
    print(f"Estructuras: {estructuras}")
    # Aquí va el estudio comparativo de las estructuras seleccionadas
